# %% [markdown]
# # Model Behavioral Testing Framework - Quick Start
#
# This notebook demonstrates the basic usage of the Model Behavioral Testing Framework.
#
# ## Disclaimer
#
# ⚠️ **IMPORTANT**: This framework is for research and educational purposes only. Results may be unstable or misleading. Not suitable for regulated decisions without human review.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Import framework components
from src import DataLoader, ModelFactory, BehavioralTester, set_seed, setup_logging

# Set up logging
setup_logging("INFO")

# Set random seed for reproducibility
set_seed(42)

print("Framework imported successfully!")
